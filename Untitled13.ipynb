# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaidurga/DWDM/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv("//content/priya.csv")
dataset
# Out:
#      Age   salary
# 0   50.0  45000.0
# 1   45.0  15000.0
# 2   60.0   1500.0
# 3    NaN      NaN
# 4   65.0   2000.0
# 5   75.0  46000.0
# 6   79.0  55000.0
# 7    NaN      NaN
# 8   35.0  25000.0
# 9   40.0  13000.0
# 10  55.0  19000.0
# 11   NaN      NaN

# %%
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,-1].values
print('independent variable(X):',X)
print('dpendent variable(Y):',Y)
# Out:
# independent variable(X): [[50.]
#  [45.]
#  [60.]
#  [nan]
#  [65.]
#  [75.]
#  [79.]
#  [nan]
#  [35.]
#  [40.]
#  [55.]
#  [nan]]
# dpendent variable(Y): [45000. 15000.  1500.    nan  2000. 46000. 55000.    nan 25000. 13000.
#  19000.    nan]

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
X=imp.fit_transform(X)
Y=Y.reshape(-1,1)
Y=imp.fit_transform(Y)
Y=Y.reshape(-1)
print(X)
print(Y)
# Out:
# [[50.]
#  [45.]
#  [60.]
#  [56.]
#  [65.]
#  [75.]
#  [79.]
#  [56.]
#  [35.]
#  [40.]
#  [55.]
#  [56.]]
# [45000.         15000.          1500.         24611.11111111
#   2000.         46000.         55000.         24611.11111111
#  25000.         13000.         19000.         24611.11111111]

# %%
from os import XATTR_REPLACE
#convert X and Y to DataFrame
X_df=pd.DataFrame(X, columns=dataset.columns[:-1])
Y_df=pd.DataFrame(Y,columns=[dataset.columns[-1]])
combined_data=pd.concat([X_df,Y_df],axis=1)
print("combined data:")
print(combined_data)
# Out:
# combined data:
#      Age        salary
# 0   50.0  45000.000000
# 1   45.0  15000.000000
# 2   60.0   1500.000000
# 3   56.0  24611.111111
# 4   65.0   2000.000000
# 5   75.0  46000.000000
# 6   79.0  55000.000000
# 7   56.0  24611.111111
# 8   35.0  25000.000000
# 9   40.0  13000.000000
# 10  55.0  19000.000000
# 11  56.0  24611.111111

# %%
combined_df=pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("combined dataframe:")
print(combined_df.head())
# Out:
# combined dataframe:
#     Age        salary
# 0  50.0  45000.000000
# 1  45.0  15000.000000
# 2  60.0   1500.000000
# 3  56.0  24611.111111
# 4  65.0   2000.000000
